# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamthakur6228/shubham-thakur/blob/main/(data_science)_practical_no_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing libraries
import pandas as pd

#importing data
data=pd.read_csv("movies.csv")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-177cf70ef585> in <cell line: 5>()
#       3
#       4 #importing data
# ----> 5 data=pd.read_csv("movies.csv")
#       6 data
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c5d84736ba45> in <cell line: 1>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
#import libraries
import pandas as pd
#importing data
data=pd.read_excel("movies.xlsx")
data
# Out:
#      name;"rating";"genre";"year";"released";"score";"votes";"director";"writer";"star";"country";"budget";"gross";"company";"runtime"  \
# 0                 The Shining;"R";"Drama";1980;"June 13
# 1          The Blue Lagoon;"R";"Adventure";1980;"July 2
# 2     Star Wars: Episode V - The Empire Strikes Back...
# 3                  Airplane!;"PG";"Comedy";1980;"July 2
# 4                 Caddyshack;"R";"Comedy";1980;"July 25
# ...                                                 ...
# 3995        Birthday Girl;"R";"Comedy";2001;"February 1
# 3996       Human Nature;"R";"Comedy";2001;"September 12
# 3997                  Made;"R";"Comedy";2001;"August 31
# 3998  One Night at McCool's;"R";"Comedy";2001;"April 27
# 3999         Dr. Dolittle 2;"PG";"Comedy";2001;"June 22
#
#                                              Unnamed: 1 Unnamed: 2
# 0      1980 (United States)";8.4;927000.0;"Stanley K...        NaN
# 1      1980 (United States)";5.8;65000.0;"Randal Kle...        NaN
# ...

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img=mpimg.imread("images.jpg")
plt.imshow(img)

# %%
import pandas as pd
df=pd.DataFrame(
    {'Roll no':[6221,6223,6224,6225,6226,6221],
     'Name':['soham','harsh','vinay','vivek','shubham','soham'],
     'Marks':[40,20,27,30,24,40]})
print(df)
# Out:
#    Roll no     Name  Marks
# 0     6221    soham     40
# 1     6223    harsh     20
# 2     6224    vinay     27
# 3     6225    vivek     30
# 4     6226  shubham     24
# 5     6221    soham     40

# %%
df.isnull()
# Out:
#    Roll no   Name  Marks
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False
# 3    False  False  False
# 4    False  False  False
# 5    False  False  False

# %%
df.isnull().sum()
# Out:
# Roll no    0
# Name       0
# Marks      0
# dtype: int64

# %%
df.describe()
# Out:
#            Roll no      Marks
# count     6.000000   6.000000
# mean   6223.333333  30.166667
# std       2.065591   8.304617
# min    6221.000000  20.000000
# 25%    6221.500000  24.750000
# 50%    6223.500000  28.500000
# 75%    6224.750000  37.500000
# max    6226.000000  40.000000

# %%
df.describe(include='object')
# Out:
#          Name
# count       6
# unique      5
# top     soham
# freq        2

# %%
df.shape
# Out:
# (6, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll no  6 non-null      int64
#  1   Name     6 non-null      object
#  2   Marks    6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 272.0+ bytes

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.nunique()
# Out:
# Roll no    5
# Name       5
# Marks      5
# dtype: int64

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of    Roll no     Name  Marks
# 0     6221    soham     40
# 1     6223    harsh     20
# 2     6224    vinay     27
# 3     6225    vivek     30
# 4     6226  shubham     24
# 5     6221    soham     40>

# %%
df['Name']
# Out:
# 0      soham
# 1      harsh
# 2      vinay
# 3      vivek
# 4    shubham
# 5      soham
# Name: Name, dtype: object

# %%
df['Name'].value_counts()
# Out:
# soham      2
# harsh      1
# vinay      1
# vivek      1
# shubham    1
# Name: Name, dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-135-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           Roll no     Marks
# Roll no  1.000000 -0.715093
# Marks   -0.715093  1.000000

# %%
import seaborn as sns
correlation=df.corr()
sns.heatmap(correlation,annot=True,fmt=".3f",cmap='viridis')
# Out:
# <ipython-input-138-d2974c7070f5>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()
# <Axes: >

# %%
df.var()
# Out:
# <ipython-input-140-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Roll no     4.266667
# Marks      68.966667
# dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-141-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Roll no    6223.333333
# Marks        30.166667
# dtype: float64

# %%
df['Roll no'].var()
# Out:
# 4.266666666666667

# %%
df.cov()
# Out:
# <ipython-input-144-6f98a29763d5>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#            Roll no      Marks
# Roll no   4.266667 -12.266667
# Marks   -12.266667  68.966667
